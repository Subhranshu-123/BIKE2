# %% [markdown]
# <a href="https://colab.research.google.com/github/Subhranshu-123/BIKE2/blob/main/Copy_of_JAVA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://github.com/SpencerPark/IJava/releases/download/v1.3.0/ijava-1.3.0.zip
# !unzip ijava-1.3.0.zip
# !python3 install.py --sys-prefix
# Out:
# --2026-04-09 05:20:08--  https://github.com/SpencerPark/IJava/releases/download/v1.3.0/ijava-1.3.0.zip
# Resolving github.com (github.com)... 20.27.177.113
# Connecting to github.com (github.com)|20.27.177.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !javac MyClass.java
# !java MyClass
# Out:
# Java is running on Colab!

# %%
# %%writefile MyClass.java
# public class MyClass {
#     public static void main(String[] args) {
#         System.out.println("Java is running on Colab!");
#     }
# }
# Out:
# Overwriting MyClass.java

# %%
# !javac MyClass.java
# !java MyClass
# Out:
# Java is running on Colab!

# %%
# %%writefile Main.java
# public class Main {
#     public static void main(String[] args) {
#         int a = 20;
#         int b = 10;
#
#         // Simple math queries
#         int sum = add(a, b);
#         int diff = subtract(a, b);
#
#         System.out.println("Queries for " + a + " and " + b + ":");
#         System.out.println("Addition: " + sum);
#         System.out.println("Subtraction: " + diff);
#     }
#
#     public static int add(int x, int y) {
#         return x + y;
#     }
#
#     public static int subtract(int x, int y) {
#         return x - y;
#     }
# }
# Out:
# Writing Main.java

# %%
# !javac Main.java
# !java Main
# Out:
# Queries for 20 and 10:
# Addition: 30
# Subtraction: 10

# %%
# %%writefile Main.java
# import java.util.Scanner;
#
# public class Main {
#     public static void main(String[] args) {
#         Scanner sc = new Scanner(System.in);
#
#         System.out.print("Enter first number: ");
#         int a = sc.nextInt();
#
#         System.out.print("Enter second number: ");
#         int b = sc.nextInt();
#
#         System.out.println("\nResults:");
#         System.out.println("Addition: " + (a + b));
#         System.out.println("Subtraction: " + (a - b));
#
#         sc.close(); // Good practice to release resources
#     }
# }
# Out:
# Overwriting Main.java

# %%
# !javac Main.java
# !java Main
# Out:
# Enter first number:

# %%
# !javac Main.java
# !java Main
# Out:
# Queries for 20 and 10:
# Addition: 30
# Subtraction: 10

# %%
# !javac Main.java
# !java Main
# Out:
# Enter first number:

# %%
# %%writefile Main.java
# import java.util.Scanner;
#
# public class Main {
#     public static void main(String[] args) {
#         Scanner sc = new Scanner(System.in);
#
#         System.out.println("--- Java Calculator Menu ---");
#         System.out.println("1. Add");
#         System.out.println("2. Subtract");
#         System.out.print("Choose an option (1 or 2): ");
#         int choice = sc.nextInt();
#
#         System.out.print("Enter first number: ");
#         int num1 = sc.nextInt();
#         System.out.print("Enter second number: ");
#         int num2 = sc.nextInt();
#
#         switch (choice) {
#             case 1:
#                 System.out.println("Result: " + (num1 + num2));
#                 break;
#             case 2:
#                 System.out.println("Result: " + (num1 - num2));
#                 break;
#             default:
#                 System.out.println("Invalid choice! Please select 1 or 2.");
#                 break;
#         }
#         sc.close();
#     }
# }
# Out:
# Overwriting Main.java

# %%
# !javac Main.java
# !java Main
# Out:
# --- Java Calculator Menu ---
# 1. Add
# 2. Subtract
# Choose an option (1 or 2):

# %%
# %%writefile Main.java
# import java.util.Scanner;
#
# public class Main {
#     public static void main(String[] args) {
#         Scanner sc = new Scanner(System.in);
#
#         while (true) {
#             System.out.println("\n--- Java Calculator ---");
#             System.out.println("1. Add");
#             System.out.println("2. Subtract");
#             System.out.println("3. Exit");
#             System.out.print("Choose an option: ");
#
#             int choice = sc.nextInt();
#
#             if (choice == 3) {
#                 System.out.println("Exiting... Goodbye!");
#                 break; // This breaks the while loop
#             }
#
#             System.out.print("Enter first number: ");
#             int num1 = sc.nextInt();
#             System.out.print("Enter second number: ");
#             int num2 = sc.nextInt();
#
#             switch (choice) {
#                 case 1:
#                     System.out.println("Result: " + (num1 + num2));
#                     break;
#                 case 2:
#                     System.out.println("Result: " + (num1 - num2));
#                     break;
#                 default:
#                     System.out.println("Invalid choice! Try again.");
#             }
#         }
#         sc.close();
#     }
# }
# Out:
# Overwriting Main.java

# %%
# !javac Main.java
# !java Main
# Out:
# --- Java Calculator ---
# 1. Add
# 2. Subtract
# 3. Exit
# Choose an option: 12
# Enter first number: 34
# Enter second number: 23
# Invalid choice! Try again.
#
# --- Java Calculator ---
# 1. Add
# 2. Subtract
# 3. Exit
# Choose an option: 1
# Enter first number: 23
# Enter second number: 34
# Result: 57
#
# --- Java Calculator ---
# 1. Add
# 2. Subtract
# 3. Exit
# Choose an option: 3
# Exiting... Goodbye!

# %%
# %%writefile Main.java
# import java.util.Scanner;
#
# public class Main {
#     public static void main(String[] args) {
#         Scanner sc = new Scanner(System.in);
#
#         while (true) {
#             System.out.println("\n--- Java Calculator ---");
#             System.out.println("1. Add / Subtract / Multiply / Divide");
#             System.out.println("2. Check Even or Odd");
#             System.out.println("3. Exit");
#             System.out.print("Choose an option: ");
#
#             int choice = sc.nextInt();
#
#             if (choice == 3) {
#                 System.out.println("Exiting... Goodbye!");
#                 break;
#             }
#
#             if (choice == 2) {
#                 System.out.print("Enter a number to check: ");
#                 int num = sc.nextInt();
#                 if (num % 2 == 0) {
#                     System.out.println(num + " is EVEN.");
#                 } else {
#                     System.out.println(num + " is ODD.");
#                 }
#                 continue; // Skips the rest of the loop and starts over
#             }
#
#             // Standard Math Logic for Choice 1
#             if (choice == 1) {
#                 System.out.println("Select: 1.Add 2.Sub 3.Mul 4.Div");
#                 int op = sc.nextInt();
#                 System.out.print("Num 1: "); double n1 = sc.nextDouble();
#                 System.out.print("Num 2: "); double n2 = sc.nextDouble();
#
#                 switch (op) {
#                     case 1: System.out.println("Result: " + (n1 + n2)); break;
#                     case 2: System.out.println("Result: " + (n1 - n2)); break;
#                     case 3: System.out.println("Result: " + (n1 * n2)); break;
#                     case 4: System.out.println(n2 != 0 ? "Result: " + (n1 / n2) : "Error: Div by 0"); break;
#                 }
#             }
#         }
#         sc.close();
#     }
# }
# Out:
# Overwriting Main.java

# %%
# !javac Main.java
# !java Main
# Out:
# --- Java Calculator ---
# 1. Add / Subtract / Multiply / Divide
# 2. Check Even or Odd
# 3. Exit
# Choose an option: 1
# Select: 1.Add 2.Sub 3.Mul 4.Div
# 1
# Num 1: 4
# Num 2: 6
# Result: 10.0
#
# --- Java Calculator ---
# 1. Add / Subtract / Multiply / Divide
# 2. Check Even or Odd
# 3. Exit
# Choose an option: 2
# Enter a number to check: 34
# 34 is EVEN.
#
# --- Java Calculator ---
# 1. Add / Subtract / Multiply / Divide
# 2. Check Even or Odd
# 3. Exit
# Choose an option: 3
# Exiting... Goodbye!

# %%
# %%writefile Main.java
# import java.util.Scanner;
#
# public class Main {
#     public static void main(String[] args) {
#         Scanner sc = new Scanner(System.in);
#
#         while (true) {
#             System.out.println("\n--- Java Calculator ---");
#             System.out.println("1. Basic Math (Add, Sub, Mul, Div)");
#             System.out.println("2. Check Even or Odd");
#             System.out.println("3. Check Prime Number");
#             System.out.println("4. Exit");
#             System.out.print("Choose an option: ");
#
#             int choice = sc.nextInt();
#
#             if (choice == 4) {
#                 System.out.println("Exiting... Goodbye!");
#                 break;
#             }
#
#             if (choice == 3) {
#                 System.out.print("Enter a number to check for primality: ");
#                 int num = sc.nextInt();
#                 if (isPrime(num)) {
#                     System.out.println(num + " is a PRIME number.");
#                 } else {
#                     System.out.println(num + " is NOT a prime number.");
#                 }
#                 continue;
#             }
#
#             if (choice == 2) {
#                 System.out.print("Enter a number to check even/odd: ");
#                 int num = sc.nextInt();
#                 System.out.println(num + " is " + (num % 2 == 0 ? "EVEN." : "ODD."));
#                 continue;
#             }
#
#             if (choice == 1) {
#                 System.out.println("Select: 1.Add 2.Sub 3.Mul 4.Div");
#                 int op = sc.nextInt();
#                 System.out.print("Num 1: "); double n1 = sc.nextDouble();
#                 System.out.print("Num 2: "); double n2 = sc.nextDouble();
#
#                 switch (op) {
#                     case 1: System.out.println("Result: " + (n1 + n2)); break;
#                     case 2: System.out.println("Result: " + (n1 - n2)); break;
#                     case 3: System.out.println("Result: " + (n1 * n2)); break;
#                     case 4: System.out.println(n2 != 0 ? "Result: " + (n1 / n2) : "Error: Div by 0"); break;
#                 }
#             }
#         }
#         sc.close();
#     }
#
#     // Helper method to check if a number is prime
#     public static boolean isPrime(int n) {
#         if (n <= 1) return false; // 0 and 1 are not prime
#         for (int i = 2; i <= Math.sqrt(n); i++) { // Only check up to square root for speed
#             if (n % i == 0) return false;
#         }
#         return true;
#     }
# }
# Out:
# Overwriting Main.java

# %%
# !javac Main.java
# !java Main
# Out:
# --- Java Calculator ---
# 1. Basic Math (Add, Sub, Mul, Div)
# 2. Check Even or Odd
# 3. Check Prime Number
# 4. Exit
# Choose an option: 1
# Select: 1.Add 2.Sub 3.Mul 4.Div
# 2
# Num 1: 6
# Num 2: 2
# Result: 4.0
#
# --- Java Calculator ---
# 1. Basic Math (Add, Sub, Mul, Div)
# 2. Check Even or Odd
# 3. Check Prime Number
# 4. Exit
# Choose an option: 3
# Enter a number to check for primality: 4
# 4 is NOT a prime number.
#
# --- Java Calculator ---
# 1. Basic Math (Add, Sub, Mul, Div)
# 2. Check Even or Odd
# 3. Check Prime Number
# 4. Exit
# Choose an option: 4
# Exiting... Goodbye!
