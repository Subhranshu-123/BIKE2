# %% [markdown]
# <a href="https://colab.research.google.com/github/Subhranshu-123/BIKE2/blob/main/practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
df=pd.read_excel('Online Retail.xlsx')

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.shape
# Out:
# (541909, 8)

# %%
df.describe()
# Out:
#             Quantity                    InvoiceDate      UnitPrice  \
# count  541909.000000                         541909  541909.000000
# mean        9.552250  2011-07-04 13:34:57.156386048       4.611114
# min    -80995.000000            2010-12-01 08:26:00  -11062.060000
# 25%         1.000000            2011-03-28 11:34:00       1.250000
# 50%         3.000000            2011-07-19 17:17:00       2.080000
# 75%        10.000000            2011-10-19 11:27:00       4.130000
# max     80995.000000            2011-12-09 12:50:00   38970.000000
# std       218.081158                            NaN      96.759853
#
#           CustomerID
# count  406829.000000
# mean    15287.690570
# min     12346.000000
# 25%     13953.000000
# 50%     15152.000000
# 75%     16791.000000
# max     18287.000000
# std      1713.600303

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135037
# Country             0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.shape
# Out:
# (401604, 8)

# %%
df.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
df.describe()
# Out:
#             Quantity                    InvoiceDate      UnitPrice  \
# count  401604.000000                         401604  401604.000000
# mean       12.183273  2011-07-10 12:08:23.848567552       3.474064
# min    -80995.000000            2010-12-01 08:26:00       0.000000
# 25%         2.000000            2011-04-06 15:02:00       1.250000
# 50%         5.000000            2011-07-29 15:40:00       1.950000
# 75%        12.000000            2011-10-20 11:58:30       3.750000
# max     80995.000000            2011-12-09 12:50:00   38970.000000
# std       250.283037                            NaN      69.764035
#
#           CustomerID
# count  401604.000000
# mean    15281.160818
# min     12346.000000
# 25%     13939.000000
# 50%     15145.000000
# 75%     16784.000000
# max     18287.000000
# std      1714.006089

# %%
id(df)
# Out:
# 133700531055568

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 401604 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    401604 non-null  object
#  1   StockCode    401604 non-null  object
#  2   Description  401604 non-null  object
#  3   Quantity     401604 non-null  int64
#  4   InvoiceDate  401604 non-null  datetime64[ns]
#  5   UnitPrice    401604 non-null  float64
#  6   CustomerID   401604 non-null  float64
#  7   Country      401604 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 27.6+ MB

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.to_csv('Online Retail.csv')

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.shape
# Out:
# (401604, 8)

# %%
df.groupby(['InvoiceNo','StockCode'])

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.describe()
# Out:
#             Quantity                    InvoiceDate      UnitPrice  \
# count  401604.000000                         401604  401604.000000
# mean       12.183273  2011-07-10 12:08:23.848567552       3.474064
# min    -80995.000000            2010-12-01 08:26:00       0.000000
# 25%         2.000000            2011-04-06 15:02:00       1.250000
# 50%         5.000000            2011-07-29 15:40:00       1.950000
# 75%        12.000000            2011-10-20 11:58:30       3.750000
# max     80995.000000            2011-12-09 12:50:00   38970.000000
# std       250.283037                            NaN      69.764035
#
#           CustomerID
# count  401604.000000
# mean    15281.160818
# min     12346.000000
# 25%     13939.000000
# 50%     15145.000000
# 75%     16784.000000
# max     18287.000000
# std      1714.006089

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 401604 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    401604 non-null  object
#  1   StockCode    401604 non-null  object
#  2   Description  401604 non-null  object
#  3   Quantity     401604 non-null  int64
#  4   InvoiceDate  401604 non-null  datetime64[ns]
#  5   UnitPrice    401604 non-null  float64
#  6   CustomerID   401604 non-null  float64
#  7   Country      401604 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 27.6+ MB

# %%
import statistics as st
import math

# %%
df['Quantity']==6
# Out:
# 0          True
# 1          True
# 2         False
# 3          True
# 4          True
#           ...
# 541904    False
# 541905     True
# 541906    False
# 541907    False
# 541908    False
# Name: Quantity, Length: 401604, dtype: bool

# %%
df_filtered=df[(df['Quantity']>=6) & (df['CustomerID']==17850.0)]
display(df_filtered)
# Out:
#      InvoiceNo StockCode                          Description  Quantity  \
# 0       536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365     71053                  WHITE METAL LANTERN         6
# 2       536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...       ...                                  ...       ...
# 4538    536790    84029G  KNITTED UNION FLAG HOT WATER BOTTLE        12
# 4539    536790    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 4542    536790     21730    GLASS STAR FROSTED T-LIGHT HOLDER        12
# 4543    536791     22632            HAND WARMER RED POLKA DOT        12
# 4544    536791     22633               HAND WARMER UNION JACK        12
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df2=df[(df['StockCode']=="84029G") & (df['CustomerID']==17850.0)]
display(df2)
# Out:
#      InvoiceNo StockCode                          Description  Quantity  \
# 3       536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 61      536373    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 78      536375    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 291     536396    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 428     536406    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 3125    536600    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 3138    536602    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 3204    536609    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 3236    536612    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 3437    536628    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 3455    536630    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 3820    536685    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         8
# ...

# %%
df_Quantity=df['Quantity'].mean()
display(df_Quantity)
# Out:
# 12.183272576966365

# %%
df_Quantity=df['Quantity'].std()
display(df_Quantity)
# Out:
# 250.28303714444849

# %%
df_unitprice=df['UnitPrice'].std()
display(df_unitprice)
# Out:
# 69.76403506412308

# %%
df_unitprice=df['UnitPrice'].mean()
display(df_unitprice)
# Out:
# 3.4740636398043865

# %%
df2_filtered=df[(df['Country']=='United Kingdom') & (df['CustomerID']==17850.0)]
display(df2_filtered)
# Out:
#       InvoiceNo StockCode                          Description  Quantity  \
# 0        536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1        536365     71053                  WHITE METAL LANTERN         6
# 2        536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3        536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4        536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...         ...       ...                                  ...       ...
# 86896   C543611     21071       VINTAGE BILLBOARD DRINK ME MUG        -6
# 86897   C543611     82483   WOOD 2 DRAWER CABINET WHITE FINISH        -2
# 86899   C543611     21874                    GIN AND TONIC MUG        -1
# 86900   C543611     71477    COLOUR GLASS. STAR T-LIGHT HOLDER        -2
# 86902   C543611     21169      YOU'RE CONFUSING ME METAL SIGN         -2
#
#               InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df3_filtered=df[(df['Country']=='France')& (df['UnitPrice']==3.75)]
display(df3_filtered)
# Out:
#        InvoiceNo StockCode                     Description  Quantity  \
# 26        536370     22728       ALARM CLOCK BAKELIKE PINK        24
# 27        536370     22727       ALARM CLOCK BAKELIKE RED         24
# 28        536370     22726      ALARM CLOCK BAKELIKE GREEN        12
# 41        536370     21913  VINTAGE SEASIDE JIGSAW PUZZLES        12
# 7905      537065     22727       ALARM CLOCK BAKELIKE RED          4
# ...          ...       ...                             ...       ...
# 534791    581171     21481      FAWN BLUE HOT WATER BOTTLE         4
# 541897    581587     22728       ALARM CLOCK BAKELIKE PINK         4
# 541898    581587     22727       ALARM CLOCK BAKELIKE RED          4
# 541899    581587     22726      ALARM CLOCK BAKELIKE GREEN         4
# 541900    581587     22730      ALARM CLOCK BAKELIKE IVORY         4
#
#                InvoiceDate  UnitPrice  CustomerID Country
# 26     2010-12-01 08:45:00       3.75     12583.0  France
# ...

# %%
df2_filtered=df[(df['Country']=='United Kingdom') & (df['InvoiceNo']=="C543611")]
display(df2_filtered)
# Out:
#       InvoiceNo StockCode                         Description  Quantity  \
# 86888   C543611     82483  WOOD 2 DRAWER CABINET WHITE FINISH        -1
# 86889   C543611     22632           HAND WARMER RED RETROSPOT        -6
# 86891   C543611     21871                 SAVE THE PLANET MUG        -1
# 86892   C543611    82494L         WOODEN FRAME ANTIQUE WHITE         -2
# 86893   C543611     21730   GLASS STAR FROSTED T-LIGHT HOLDER        -1
# 86894   C543611     21730   GLASS STAR FROSTED T-LIGHT HOLDER        -1
# 86895   C543611    82494L         WOODEN FRAME ANTIQUE WHITE        -12
# 86896   C543611     21071      VINTAGE BILLBOARD DRINK ME MUG        -6
# 86897   C543611     82483  WOOD 2 DRAWER CABINET WHITE FINISH        -2
# 86899   C543611     21874                   GIN AND TONIC MUG        -1
# 86900   C543611     71477   COLOUR GLASS. STAR T-LIGHT HOLDER        -2
# 86902   C543611     21169     YOU'RE CONFUSING ME METAL SIGN         -2
#
# ...

# %%
#plot
import matplotlib.pyplot as plt
import seaborn as sns
plot=sns.countplot(x='Quantity',data=df)

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plot2=sns.histplot(x="Quantity",y='UnitPrice',data=df)
plot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fd7c85437627> in <cell line: 0>()
#       1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
# ----> 3 plot2=sns.histplot(x="Quantity",y='UnitPrice',data=df)
#       4 plot.show()
#
# NameError: name 'df' is not defined

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Quantity', bins=50)
plt.title('Distribution of Quantity')
plt.xlabel('Quantity')
plt.ylabel('Frequency')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-14fca824bdec> in <cell line: 0>()
#       3
#       4 plt.figure(figsize=(10, 6))
# ----> 5 sns.histplot(data=df, x='Quantity', bins=50)
#       6 plt.title('Distribution of Quantity')
#       7 plt.xlabel('Quantity')
#
# NameError: name 'df' is not defined

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='UnitPrice', bins=50)
plt.title('Distribution of UnitPrice')
plt.xlabel('UnitPrice')
plt.ylabel('Frequency')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-726fbf9af088> in <cell line: 0>()
#       3
#       4 plt.figure(figsize=(10, 6))
# ----> 5 sns.histplot(data=df, x='UnitPrice', bins=50)
#       6 plt.title('Distribution of UnitPrice')
#       7 plt.xlabel('UnitPrice')
#
# NameError: name 'df' is not defined

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Quantity', bins=10)
plt.title('Distribution of Quantity')
plt.xlabel('Quantity')
plt.ylabel('Frequency')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Quantity', bins=50)
plt.title('Distribution of Quantity')
plt.xlabel('Quantity')
plt.ylabel('UnitPrice')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Quantity', bins=50,color='pink')
plt.title('Distribution of Quantity')
plt.xlabel('Quantity')
plt.ylabel('UnitPrice')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Quantity', bins=50,color='pink')
plt.title('Distribution of Quantity')
plt.xlabel('Quantity')
plt.ylabel('CustomerID')
plt.show()

# %%
import numpy as np
# !pip install scipy
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['country']=le.fit_transform(df['Country'])

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  country
# ...

# %%
df4= df.drop('Country',axis=1,inplace=True)
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID  country
# ...

# %%
#standard _scaler=x-xmin/xmax-xmin
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
df['Quantity']=scaler.fit_transform(df[['Quantity']])
df['UnitPrice']=scaler.fit_transform(df[['UnitPrice']])
df['CustomerID']=scaler.fit_transform(df[['CustomerID']])

# %%
print(df['CustomerID'])
# Out:
# 0         1.498736
# 1         1.498736
# 2         1.498736
# 3         1.498736
# 4         1.498736
#             ...
# 541904   -1.517593
# 541905   -1.517593
# 541906   -1.517593
# 541907   -1.517593
# 541908   -1.517593
# Name: CustomerID, Length: 401604, dtype: float64

# %%
print(df['Quantity'])
# Out:
# 0        -0.024705
# 1        -0.024705
# 2        -0.016714
# 3        -0.024705
# 4        -0.024705
#             ...
# 541904   -0.000732
# 541905   -0.024705
# 541906   -0.032696
# 541907   -0.032696
# 541908   -0.036692
# Name: Quantity, Length: 401604, dtype: float64

# %%
print(df['UnitPrice'])
# Out:
# 0        -0.013246
# 1        -0.001205
# 2        -0.010379
# 3        -0.001205
# 4        -0.001205
#             ...
# 541904   -0.037613
# 541905   -0.019696
# 541906    0.009689
# 541907    0.009689
# 541908    0.021156
# Name: UnitPrice, Length: 401604, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x=df['CustomerID']
y=df['Quantity']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(x_train)
# Out:
# 109423    0.681352
# 480657    1.475982
# 451386   -1.320394
# 13199     1.476566
# 198759   -1.379904
#             ...
# 357627    0.406556
# 490115   -1.143032
# 189554   -0.634281
# 208199   -1.453416
# 175748    1.431641
# Name: CustomerID, Length: 321283, dtype: float64

# %%
print(y_train)
# Out:
# 109423   -0.000732
# 480657   -0.044683
# 451386   -0.000732
# 13199    -0.044683
# 198759   -0.016714
#             ...
# 357627   -0.000732
# 490115   -0.032696
# 189554   -0.024705
# 208199   -0.024705
# 175748    0.047214
# Name: Quantity, Length: 321283, dtype: float64

# %%
print(x_test)
# Out:
# 84050     0.613090
# 312069   -1.477920
# 363834    1.239110
# 168161   -1.208959
# 216938   -0.215963
#             ...
# 262437    1.717522
# 475801   -0.365321
# 230193   -0.301143
# 43613     0.559998
# 517508   -0.717712
# Name: CustomerID, Length: 80321, dtype: float64

# %%
print(y_test)
# Out:
# 84050    -0.044683
# 312069   -0.036692
# 363834   -0.032696
# 168161   -0.000732
# 216938   -0.044683
#             ...
# 262437   -0.008723
# 475801   -0.000732
# 230193   -0.044683
# 43613    -0.044683
# 517508    0.191051
# Name: Quantity, Length: 80321, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

model = LinearRegression()
model.fit(x_train.values.reshape(-1,1), y_train)
# Out:
# LinearRegression()

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [-0.00321622]
# -1.5018595312032405e-05

# %%
print(mean_squared_error,(y_test))
# Out:
# <function mean_squared_error at 0x7c792834c7c0> 84050    -0.044683
# 312069   -0.036692
# 363834   -0.032696
# 168161   -0.000732
# 216938   -0.044683
#             ...
# 262437   -0.008723
# 475801   -0.000732
# 230193   -0.044683
# 43613    -0.044683
# 517508    0.191051
# Name: Quantity, Length: 80321, dtype: float64

# %%
print(r2_score)
# Out:
# <function r2_score at 0x7c792834cfe0>

# %%
print(r2_score)
# Out:
# <function r2_score at 0x7c792834cfe0>

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

model = LinearRegression()
model.fit(x_train.values.reshape(-1,1), y_train)
# Out:
# LinearRegression()

# %%
print(0x7c792834cfe0)
# Out:
# 136859807436768

# %%
#r2 score=0.13
